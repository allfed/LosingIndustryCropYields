# %% [markdown]
# # Setup (only run this section if using Colab)

# %%
# We must clone the code repo into your Colab environment in order to use it.
# To do this we must first connect your GitHub account via this online command line.
# Run this block, and hit Enter on each prompt, not entering any text.
# This generates an SSH key which you'll add to your GitHub account.
# !ssh-keygen -t rsa -b 4096

# %%
# !ssh-keyscan -t rsa github.com >> /root/.ssh/known_hosts

# %%
# This line prints the key. Copy the key to your clipboard.
# !cat /root/.ssh/id_rsa.pub

# %%
# Now, navigate to https://github.com/settings/keys and click "New SSH key"
# Copy paste the above into the "Key" field, and give it a title, e.g. "Colab key",
# then save the key. Once done, test using this line:
# !ssh -T git@github.com

# %%
## Now we can clone the repo using SSH
# !rm -rf CropOpt/
# !git clone -b standardize git@github.com:allfed/CropOpt.git

# %%
# This adds the Python files in our CropOpt repo to our path so we can import
# them

import os
import sys

module_path = os.path.abspath(os.path.join('./CropOpt'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Now we'll install other dependencies from our Poetry file. We do this by first
# installing the toml package so we can read the pyproject.toml file
# !pip install toml

# %%
# We then load the file and read our required packages from it
import toml
config = toml.load("CropOpt/pyproject.toml")
pip_packages = config["tool"]["poetry"]["dependencies"]

# %%
# Finally, we install the packages

import subprocess
import sys

def install_pip_package(package, version):
    subprocess.check_call([sys.executable, "-m", "pip", "install", f"{package}=={version}"])

for package, version in pip_packages.items():
    if package == "python":
        continue
    install_pip_package(package, version[1:])

# %% [markdown]
# # End of Colab-specific setup

# %% [markdown]
# # Import and Process Datasets

# %% [markdown]
# The purpose of this file is to show what variables can be imported from the nuclear winter model, and the grow area dataset from the FAO. There are two types of nuclear winter model datasets: CLM2 and CAM. CLM2 is a land dataset, while CAM is atmospheric. There are useful variables in both for our purposes.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src import params

# %%
# Import the grow area data.4
#
#   When imported, import_grow_area_data.py is run.
#
#   ImportGrowAreaData.py imports data from
#       https://github.com/allfed/CropOpt/tree/master/Data/CropArea
#
#   ImportGrowAreaData.py then saves it in geopandas format to 
#       https://github.com/allfed/CropOpt/tree/master/Data/ImportedAsGeopandas
from src import import_grow_area_data
# Out:
# dir_path
# /home/dmrivers/Code/CropOpt/src
# reading grow area
# done reading
# /home/dmrivers/.cache/pypoetry/virtualenvs/co--V6REObM-py3.7/lib/python3.7/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Earth Surface Area, billions of hectares
# 51.0065621724088
# Total Crop Area, billions of hectares
# 1.660953375487104

# %% [markdown]
# Plots above are saved in the reports/figures directory (run code below for specific location)
#
# If you're running colab, go to the left side panel and click on the folder icon (tooltip says "Files"). You can download the figures from there.

# %%
# run this cell to see location where figures were saved from running the cells above
print("Saved figures location: " + params.figuresDir)

# %% [markdown]
# PLEASE NOTE: THE CODE BELOW WILL NOT RUN FOR YOU UNLESS YOU'VE CONTACTED ME TO GET THE TOON GROUP RAW DATA. You can reach me at morgan@allfed.info. If you want to get a certain variable saved in the imported folder (https://github.com/allfed/CropOpt/tree/master/Data/ImportedAsGeopandas) you'll need to let me know so I can run the script to import it.
#
# Only atmospheric variables listed in Params.ods are imported.
#
# You can see ALL atmospheric and land variables listed after the ImportAtmData and ImportClmData calls below, including variables that are not currently imported into https://github.com/allfed/CropOpt/tree/master/Data/ImportedAsGeopandas:

# %%
# Import some nuclear winter atmospheric dataset variables
#
#   When imported, import_atm_data.py is run.
#
#   ImportAtmData.py imports data from
#       Data/RawNuclearWinterData (if it exists, otherwise code will fail)
#
#   ImportAtmData.py then saves it in geopandas format ([varname].pkl) to 
#       https://github.com/allfed/CropOpt/tree/master/Data/ImportedAsGeopandas

from src import import_atm_data
# Out:
# params to actually import:
# ['FSNS', 'TS', 'PRECL', 'TSMN', 'Q']
#
# All possible params:
# ###
# AEROD_v
# 1
# Total Aerosol Optical Depth in visible band
# ###
# AOA1
# kg/kg
# Age-of_air tracer 1
# ###
# AOA1SRC
# kg/kg/s
# AOA1 source/sink
# ###
# AOA2
# kg/kg
# Age-of_air tracer 2
# ###
# AOA2SRC
# kg/kg/s
# AOA2 source/sink
# ###
# AOA_NH_SRF
# mol/mol
# AOA_NH in bottom layer
# ###
# BR
# mol/mol
# BR concentration
# ###
# BRCL
# mol/mol
# BRCL concentration
# ###
# BRCL_SRF
# mol/mol
# BRCL in bottom layer
# ###
# BRO
# mol/mol
# BRO concentration
# ###
# BRONO2
# mol/mol
# BRONO2 concentration
# ###
# BRONO2_SRF
# mol/mol
# BRONO2 in bottom layer
# ###
# BROX
# mol/mol
# brox (Br+BrO+BRCl+HOBr)
# ###
# BROY
# mol/mol
# total inorganic bromine (Br+BrO+HOBr+BrONO2+HBr+BrCl)
# ###
# BRO_SRF
# mol/mol
# BRO in bottom layer
# ###
# BR_SRF
# mol/mol
# BR in bottom layer
# ###
# BTAUE
# Pa
# Beres (deep) Eastward Reynolds stress
# ###
# BTAUN
# Pa
# Beres (deep) Northward Reynolds stress
# ###
# BTAUNET
# Pa
# Beres (deep) E+W Reynolds stress
# ###
# BTAUS
# Pa
# Beres (deep) Southward Reynolds stress
# ###
# BTAUW
# Pa
# Beres (deep) Westward Reynolds stress
# ###
# BTTGWSPEC
# K
# Beres (deep) T tendency - gravity wave spectrum
# ###
# BUTEND1
# m/s2
# Beres (deep) U tendency   c < -40
# ###
# BUTEND2
# m/s2
# Beres (deep) U tendency  -40 < c < -15
# ###
# BUTEND3
# m/s2
# Beres (deep) U tendency  -15 < c <  15
# ###
# BUTEND4
# m/s2
# Beres (deep) U tendency   15 < c <  40
# ###
# BUTEND5
# m/s2
# Beres (deep) U tendency   40 < c
# ###
# BUTGWSPEC
# m/s2
# Beres (deep) U tendency - gravity wave spectrum
# ###
# BVTGWSPEC
# m/s2
# Beres (deep) V tendency - gravity wave spectrum
# ###
# CCL4
# mol/mol
# CCL4 concentration
# ###
# CCL4_SRF
# mol/mol
# CCL4 in bottom layer
# ###
# CF2CLBR
# mol/mol
# CF2CLBR concentration
# ###
# CF2CLBR_SRF
# mol/mol
# CF2CLBR in bottom layer
# ###
# CF3BR
# mol/mol
# CF3BR concentration
# ###
# CF3BR_SRF
# mol/mol
# CF3BR in bottom layer
# ###
# CFC11
# mol/mol
# CFC11 concentration
# ###
# CFC113
# mol/mol
# CFC113 concentration
# ###
# CFC113_SRF
# mol/mol
# CFC113 in bottom layer
# ###
# CFC114_SRF
# mol/mol
# CFC114 in bottom layer
# ###
# CFC115_SRF
# mol/mol
# CFC115 in bottom layer
# ###
# CFC11STAR
# kg/kg
# cfc11star for radiation
# ###
# CFC11_SRF
# mol/mol
# CFC11 in bottom layer
# ###
# CFC12
# mol/mol
# CFC12 concentration
# ###
# CFC12_SRF
# mol/mol
# CFC12 in bottom layer
# ###
# CH2BR2_SRF
# mol/mol
# CH2BR2 in bottom layer
# ###
# CH2O
# mol/mol
# CH2O concentration
# ###
# CH2O_SRF
# mol/mol
# CH2O in bottom layer
# ###
# CH3BR
# mol/mol
# CH3BR concentration
# ###
# CH3BR_SRF
# mol/mol
# CH3BR in bottom layer
# ###
# CH3CCL3
# mol/mol
# CH3CCL3 concentration
# ###
# CH3CCL3_SRF
# mol/mol
# CH3CCL3 in bottom layer
# ###
# CH3CL
# mol/mol
# CH3CL concentration
# ###
# CH3CL_SRF
# mol/mol
# CH3CL in bottom layer
# ###
# CH3O2
# mol/mol
# CH3O2 concentration
# ###
# CH3O2_SRF
# mol/mol
# CH3O2 in bottom layer
# ###
# CH3OOH
# mol/mol
# CH3OOH concentration
# ###
# CH3OOH_SRF
# mol/mol
# CH3OOH in bottom layer
# ###
# CH4
# mol/mol
# CH4 concentration
# ###
# CH4_SRF
# mol/mol
# CH4 in bottom layer
# ###
# CHBR3_SRF
# mol/mol
# CHBR3 in bottom layer
# ###
# CL
# mol/mol
# CL concentration
# ###
# CL2
# mol/mol
# CL2 concentration
# ###
# CL2O2
# mol/mol
# CL2O2 concentration
# ###
# CL2O2_SRF
# mol/mol
# CL2O2 in bottom layer
# ###
# CL2_SRF
# mol/mol
# CL2 in bottom layer
# ###
# CLDHGH
# fraction
# Vertically-integrated high cloud
# ###
# CLDICE
# kg/kg
# Grid box averaged cloud ice amount
# ###
# CLDLIQ
# kg/kg
# Grid box averaged cloud liquid amount
# ###
# CLDLOW
# fraction
# Vertically-integrated low cloud
# ###
# CLDMED
# fraction
# Vertically-integrated mid-level cloud
# ###
# CLDTOT
# fraction
# Vertically-integrated total cloud
# ###
# CLO
# mol/mol
# CLO concentration
# ###
# CLONO2
# mol/mol
# CLONO2 concentration
# ###
# CLONO2_SRF
# mol/mol
# CLONO2 in bottom layer
# ###
# CLOUD
# fraction
# Cloud fraction
# ###
# CLOX
# mol/mol
# clox (Cl+CLO+HOCl+2Cl2+2Cl2O2+OClO
# ###
# CLOY
# mol/mol
# total inorganic chlorine (Cl+ClO+2Cl2+2Cl2O2+OClO+HOCl+ClONO2+HCl+BrCl)
# ###
# CLO_SRF
# mol/mol
# CLO in bottom layer
# ###
# CL_SRF
# mol/mol
# CL in bottom layer
# ###
# CO
# mol/mol
# CO concentration
# ###
# CO2
# mol/mol
# CO2 concentration
# ###
# CO2_SRF
# mol/mol
# CO2 in bottom layer
# ###
# COF2_SRF
# mol/mol
# COF2 in bottom layer
# ###
# COFCL_SRF
# mol/mol
# COFCL in bottom layer
# ###
# CONCLD
# fraction
# Convective cloud cover
# ###
# CO_25_SRF
# mol/mol
# CO_25 in bottom layer
# ###
# CO_50_SRF
# mol/mol
# CO_50 in bottom layer
# ###
# CO_SRF
# mol/mol
# CO in bottom layer
# ###
# CRSOOT01
# kg/kg
# Soot,  0.2000E-01 um
# ###
# CRSOOT02
# kg/kg
# Soot,  0.2711E-01 um
# ###
# CRSOOT03
# kg/kg
# Soot,  0.3674E-01 um
# ###
# CRSOOT04
# kg/kg
# Soot,  0.4980E-01 um
# ###
# CRSOOT05
# kg/kg
# Soot,  0.6750E-01 um
# ###
# CRSOOT06
# kg/kg
# Soot,  0.9149E-01 um
# ###
# CRSOOT07
# kg/kg
# Soot,  0.1240E+00 um
# ###
# CRSOOT08
# kg/kg
# Soot,  0.1681E+00 um
# ###
# CRSOOT09
# kg/kg
# Soot,  0.2278E+00 um
# ###
# CRSOOT10
# kg/kg
# Soot,  0.3088E+00 um
# ###
# CRSOOT11
# kg/kg
# Soot,  0.4185E+00 um
# ###
# CRSOOT12
# kg/kg
# Soot,  0.5672E+00 um
# ###
# CRSOOT13
# kg/kg
# Soot,  0.7688E+00 um
# ###
# CRSOOT14
# kg/kg
# Soot,  0.1042E+01 um
# ###
# CRSOOT15
# kg/kg
# Soot,  0.1412E+01 um
# ###
# CRSOOT16
# kg/kg
# Soot,  0.1914E+01 um
# ###
# CRSOOT17
# kg/kg
# Soot,  0.2595E+01 um
# ###
# CRSOOT18
# kg/kg
# Soot,  0.3517E+01 um
# ###
# CRSOOT19
# kg/kg
# Soot,  0.4767E+01 um
# ###
# CRSOOT20
# kg/kg
# Soot,  0.6461E+01 um
# ###
# CRSOOT21
# kg/kg
# Soot,  0.8757E+01 um
# ###
# CRSOOTAD
# um2/cm3
# CRSOOT surface area density
# ###
# CRSOOTAR
#
# CRSOOT area ratio
# ###
# CRSOOTDD
# kg/m2/s
# CRSOOT dry deposition flux at surface
# ###
# CRSOOTEM
# kg/kg/s
# CRSOOT emissions
# ###
# CRSOOTEX
# km-1
# CRSOOT extinction
# ###
# CRSOOTMD
# g/cm3
# CRSOOT mass density
# ###
# CRSOOTMR
# kg/kg
# CRSOOT mass mixing ratio
# ###
# CRSOOTND
# #/cm3
# CRSOOT number density
# ###
# CRSOOTOD
#
# CRSOOT optical depth
# ###
# CRSOOTPA
# cm2
# CRSOOT projected area
# ###
# CRSOOTRE
# um
# CRSOOT effective radius
# ###
# CRSOOTRM
# um
# CRSOOT Mitchell effective radius
# ###
# CRSOOTSW
# kg/m2/s
# CRSOOT wet deposition flux at surface
# ###
# CRSOOTVM
# m/s
# CRSOOT fall velocity
# ###
# DCQ
# kg/kg/s
# Q tendency due to moist processes
# ###
# DTCOND
# K/s
# T tendency - moist processes
# ###
# DTCORE
# K/s
# T tendency due to dynamical core
# ###
# DTV
# K/s
# T vertical diffusion
# ###
# DTWR_BRONO2
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_CH2O
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_CH3OOH
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_CLONO2
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_COF2
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_COFCL
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_H2O2
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HBR
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HCL
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HF
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HNO3
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HO2NO2
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HOBR
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_HOCL
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_NH_50W
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DTWR_SO2t
# mol/mol/s
# wet removal Neu scheme tendency
# ###
# DUV
# m/s2
# U vertical diffusion
# ###
# DVV
# m/s2
# V vertical diffusion
# ###
# E90_NH_SRF
# mol/mol
# E90_NH in bottom layer
# ###
# E90_SH_SRF
# mol/mol
# E90_SH in bottom layer
# ###
# E90_SRF
# mol/mol
# E90 in bottom layer
# ###
# EKGW
# M2/S
# Effective Kzz due to diffusion by gravity waves
# ###
# EMISCLD
# 1
# cloud emissivity
# ###
# EPOTEN
# V
# Electric Potential
# ###
# FICE
# fraction
# Fractional ice content within cloud
# ###
# FLDS
# W/m2
# Downwelling longwave flux at surface
# ###
# FLNS
# W/m2
# Net longwave flux at surface
# ###
# FLNSC
# W/m2
# Clearsky net longwave flux at surface
# ###
# FLNT
# W/m2
# Net longwave flux at top of model
# ###
# FLNTC
# W/m2
# Clearsky net longwave flux at top of model
# ###
# FLUT
# W/m2
# Upwelling longwave flux at top of model
# ###
# FLUTC
# W/m2
# Clearsky upwelling longwave flux at top of model
# ###
# FRONTGF
# K^2/M^2/S
# Frontogenesis function at gws src level
# ###
# FRONTGFA
# K^2/M^2/S
# Frontogenesis function at gws src level
# ###
# FSDS
# W/m2
# Downwelling solar flux at surface
# ###
# FSDSC
# W/m2
# Clearsky downwelling solar flux at surface
# ###
# FSNS
# W/m2
# Net solar flux at surface
# ###
# FSNSC
# W/m2
# Clearsky net solar flux at surface
# ###
# FSNT
# W/m2
# Net solar flux at top of model
# ###
# FSNTC
# W/m2
# Clearsky net solar flux at top of model
# ###
# FSNTOA
# W/m2
# Net solar flux at top of atmosphere
# ###
# FSNTOAC
# W/m2
# Clearsky net solar flux at top of atmosphere
# ###
# FSUTOA
# W/m2
# Upwelling solar flux at top of atmosphere
# ###
# F_SRF
# mol/mol
# F in bottom layer
# ###
# H
# mol/mol
# H concentration
# ###
# H1202_SRF
# mol/mol
# H1202 in bottom layer
# ###
# H2
# mol/mol
# H2 concentration
# ###
# H2402_SRF
# mol/mol
# H2402 in bottom layer
# ###
# H2O
# mol/mol
# water vapor concentration
# ###
# H2O2
# mol/mol
# H2O2 concentration
# ###
# H2O2_SRF
# mol/mol
# H2O2 in bottom layer
# ###
# H2O_SRF
# mol/mol
# water vapor in bottom layer
# ###
# H2_SRF
# mol/mol
# H2 in bottom layer
# ###
# HBR
# mol/mol
# HBR concentration
# ###
# HBR_SRF
# mol/mol
# HBR in bottom layer
# ###
# HCFC141B_SRF
# mol/mol
# HCFC141B in bottom layer
# ###
# HCFC142B_SRF
# mol/mol
# HCFC142B in bottom layer
# ###
# HCFC22
# mol/mol
# HCFC22 concentration
# ###
# HCFC22_SRF
# mol/mol
# HCFC22 in bottom layer
# ###
# HCL
# mol/mol
# HCL concentration
# ###
# HCL_SRF
# mol/mol
# HCL in bottom layer
# ###
# HDEPTH
# km
# Heating Depth
# ###
# HF_SRF
# mol/mol
# HF in bottom layer
# ###
# HNO3
# mol/mol
# HNO3 concentration
# ###
# HNO3_GAS
# mol/mol
# gas-phase hno3
# ###
# HNO3_NAT
# mol/mol
# NAT condensed HNO3
# ###
# HNO3_SRF
# mol/mol
# HNO3 in bottom layer
# ###
# HNO3_STS
# mol/mol
# STS condensed HNO3
# ###
# HO2
# mol/mol
# HO2 concentration
# ###
# HO2NO2
# mol/mol
# HO2NO2 concentration
# ###
# HO2NO2_SRF
# mol/mol
# HO2NO2 in bottom layer
# ###
# HO2_SRF
# mol/mol
# HO2 in bottom layer
# ###
# HOBR
# mol/mol
# HOBR concentration
# ###
# HOBR_SRF
# mol/mol
# HOBR in bottom layer
# ###
# HOCL
# mol/mol
# HOCL concentration
# ###
# HOCL_SRF
# mol/mol
# HOCL in bottom layer
# ###
# HORZ
# kg/kg
# horizontal tracer
# ###
# HORZSRC
# kg/kg/s
# HORZ source/sink
# ###
# H_SRF
# mol/mol
# H in bottom layer
# ###
# ICEFRAC
# fraction
# Fraction of sfc area covered by sea-ice
# ###
# ICIMR
# kg/kg
# Prognostic in-cloud ice mixing ratio
# ###
# ICWMR
# kg/kg
# Prognostic in-cloud water mixing ratio
# ###
# LANDFRAC
# fraction
# Fraction of sfc area covered by land
# ###
# LHFLX
# W/m2
# Surface latent heat flux
# ###
# LWCF
# W/m2
# Longwave cloud forcing
# ###
# MAXQ0
# K/day
# Max column heating rate
# ###
# MSKtem
# unitless
# TEM mask
# ###
# N
# mol/mol
# N concentration
# ###
# N2D_SRF
# mol/mol
# N(2D) in bottom layer
# ###
# N2O
# mol/mol
# N2O concentration
# ###
# N2O5
# mol/mol
# N2O5 concentration
# ###
# N2O5_SRF
# mol/mol
# N2O5 in bottom layer
# ###
# N2O_SRF
# mol/mol
# N2O in bottom layer
# ###
# N2p_SRF
# mol/mol
# N2+ in bottom layer
# ###
# NETDT
# K/s
# Net heating rate
# ###
# NH_50W_SRF
# mol/mol
# NH_50W in bottom layer
# ###
# NH_50_SRF
# mol/mol
# NH_50 in bottom layer
# ###
# NH_5_SRF
# mol/mol
# NH_5 in bottom layer
# ###
# NO
# mol/mol
# NO concentration
# ###
# NO2
# mol/mol
# NO2 concentration
# ###
# NO2_SRF
# mol/mol
# NO2 in bottom layer
# ###
# NO3
# mol/mol
# NO3 concentration
# ###
# NO3_SRF
# mol/mol
# NO3 in bottom layer
# ###
# NOX
# mol/mol
# nox (N+NO+NO2)
# ###
# NOY
# mol/mol
# noy = total inorganic nitrogen (N+NO+NO2+NO3+2N2O5+HNO3+HO2NO2+ORGNOY+NH4NO3
# ###
# NO_Aircraft
# molec/cm3/s
# aircraft NO source
# ###
# NO_Lightning
# molec/cm3/s
# lightning NO source
# ###
# NO_SRF
# mol/mol
# NO in bottom layer
# ###
# NOp_SRF
# mol/mol
# NO+ in bottom layer
# ###
# N_SRF
# mol/mol
# N in bottom layer
# ###
# Np_SRF
# mol/mol
# N+ in bottom layer
# ###
# O
# mol/mol
# O concentration
# ###
# O1D
# mol/mol
# O1D concentration
# ###
# O1D_SRF
# mol/mol
# O1D in bottom layer
# ###
# O2
# mol/mol
# O2 concentration
# ###
# O2_1D
# mol/mol
# O2(1-delta) concentration
# ###
# O2_1D_SRF
# mol/mol
# O2(1-delta) in bottom layer
# ###
# O2_1S
# mol/mol
# O2(1-sigma) concentration
# ###
# O2_1S_SRF
# mol/mol
# O2(1-sigma) in bottom layer
# ###
# O2_SRF
# mol/mol
# O2 in bottom layer
# ###
# O2p_SRF
# mol/mol
# O2+ in bottom layer
# ###
# O3
# mol/mol
# O3 concentration
# ###
# O3S_SRF
# mol/mol
# O3S in bottom layer
# ###
# O3_SRF
# mol/mol
# O3 in bottom layer
# ###
# OCLO
# mol/mol
# OCLO concentration
# ###
# OCLO_SRF
# mol/mol
# OCLO in bottom layer
# ###
# OCNFRAC
# fraction
# Fraction of sfc area covered by ocean
# ###
# OH
# mol/mol
# OH concentration
# ###
# OH_SRF
# mol/mol
# OH in bottom layer
# ###
# OMEGA
# Pa/s
# Vertical velocity (pressure)
# ###
# OMEGAT
# K Pa/s
# Vertical heat flux
# ###
# OMEGA_12_COS
# Pa/s
# vertical pressure velocity 12hr. cos coeff.
# ###
# OMEGA_12_SIN
# Pa/s
# vertical pressure velocity 12hr. sin coeff.
# ###
# OMEGA_24_COS
# Pa/s
# vertical pressure velocity 24hr. cos coeff.
# ###
# OMEGA_24_SIN
# Pa/s
# vertical pressure velocity 24hr. sin coeff.
# ###
# O_SRF
# mol/mol
# O in bottom layer
# ###
# Op_SRF
# mol/mol
# O+ in bottom layer
# ###
# PBLH
# m
# PBL height
# ###
# PHIS
# m2/s2
# Surface geopotential
# ###
# PRECC
# m/s
# Convective precipitation rate (liq + ice)
# ###
# PRECL
# m/s
# Large-scale (stable) precipitation rate (liq + ice)
# ###
# PRECSC
# m/s
# Convective snow rate (water equivalent)
# ###
# PRECSL
# m/s
# Large-scale (stable) snow rate (water equivalent)
# ###
# PS
# Pa
# Surface pressure
# ###
# PSL
# Pa
# Sea level pressure
# ###
# PS_12_COS
# Pa
# surface pressure 12hr. cos coeff.
# ###
# PS_12_SIN
# Pa
# surface pressure 12hr. sin coeff.
# ###
# PS_24_COS
# Pa
# surface pressure 24hr. cos coeff.
# ###
# PS_24_SIN
# Pa
# surface pressure 24hr. sin coeff.
# ###
# Q
# kg/kg
# Specific humidity
# ###
# QCP
# K/s
# chem pot heating rate
# ###
# QFLX
# kg/m2/s
# Surface water flux
# ###
# QJOULE
# K/s
# Joule Heat
# ###
# QNO
# K/s
# NO cooling
# ###
# QPERT
# kg/kg
# Perturbation specific humidity (eddies in PBL)
# ###
# QREFHT
# kg/kg
# Reference height humidity
# ###
# QRL
# K/s
# Longwave heating rate
# ###
# QRLNLTE
# K/s
# Non-LTE LW heating (includes QNO)
# ###
# QRL_TOT
# K/s
# Merged LW heating: QRL+QRLNLTE
# ###
# QRS
# K/s
# Solar heating rate
# ###
# QRS_AUR
# K/s
# total auroral heating rate
# ###
# QRS_CO2NIR
# K/s
# co2 nir heating rate
# ###
# QRS_EUV
# K/s
# total euv heating rate
# ###
# QRS_TOT
# K/s
# Merged SW heating: QRS+QCP+QRS_EUV+QRS_CO2NIR+QRS_AUR+QTHERMAL
# ###
# QTHERMAL
# K/s
# non-euv photolysis heating rate
# ###
# RELHUM
# percent
# Relative humidity
# ###
# SAD_ICE
# cm2/cm3
# water-ice aerosol SAD
# ###
# SAD_LNAT
# cm2/cm3
# large-mode NAT aerosol SAD
# ###
# SAD_SULFC
# cm2/cm3
# chemical sulfate aerosol SAD
# ###
# SF6_SRF
# mol/mol
# SF6 in bottom layer
# ###
# SF6em_SRF
# mol/mol
# SF6em in bottom layer
# ###
# SFCH2O
# kg/m2/s
# CH2O surface flux
# ###
# SFCLDICE
# kg/m2/s
# CLDICE surface flux
# ###
# SFCLDLIQ
# kg/m2/s
# CLDLIQ surface flux
# ###
# SFCO
# kg/m2/s
# CO surface flux
# ###
# SFNO
# kg/m2/s
# NO surface flux
# ###
# SHFLX
# W/m2
# Surface sensible heat flux
# ###
# SNOWHICE
# m
# Snow depth over ice
# ###
# SNOWHLND
# m
# Water equivalent snow depth
# ###
# SO2t_SRF
# mol/mol
# SO2t in bottom layer
# ###
# SOLIN
# W/m2
# Solar insolation
# ###
# ST80_25_SRF
# mol/mol
# ST80_25 in bottom layer
# ###
# SWCF
# W/m2
# Shortwave cloud forcing
# ###
# T
# K
# Temperature
# ###
# TAUE
# Pa
# C&M Eastward Reynolds stress
# ###
# TAUGWX
# N/m2
# Zonal gravity wave surface stress
# ###
# TAUGWY
# N/m2
# Meridional gravity wave surface stress
# ###
# TAUN
# Pa
# C&M Northward Reynolds stress
# ###
# TAUNET
# Pa
# C&M E+W Reynolds stress
# ###
# TAUS
# Pa
# C&M Southward Reynolds stress
# ###
# TAUW
# Pa
# C&M Westward Reynolds stress
# ###
# TAUX
# N/m2
# Zonal surface stress
# ###
# TAUY
# N/m2
# Meridional surface stress
# ###
# TCLY
# mol/mol
# total Cl (ORG+INORG) volume mixing ratio
# ###
# TGCLDCWP
# gram/m2
# Total grid-box cloud water path (liquid and ice)
# ###
# TGCLDIWP
# gram/m2
# Total grid-box cloud ice water path
# ###
# TGCLDLWP
# gram/m2
# Total grid-box cloud liquid water path
# ###
# TH
# K
# Potential Temperature
# ###
# TMQ
# kg/m2
# Total (vertically integrated) precipitable water
# ###
# TOTH
# mol/mol
# total H2 volume mixing ratio
# ###
# TREFHT
# K
# Reference height temperature
# ###
# TROPP_FD
# probability
# Tropopause Found (primary)
# ###
# TROP_P
# Pa
# Tropopause Pressure
# ###
# TROP_T
# K
# Tropopause Temperature
# ###
# TROP_Z
# m
# Tropopause Height
# ###
# TS
# K
# Surface temperature (radiative)
# ###
# TSMN
# K
# Minimum surface temperature over output period
# ###
# TSMX
# K
# Maximum surface temperature over output period
# ###
# TTGW
# K/s
# T tendency - gravity wave drag
# ###
# TTGWSPEC
# K
# C&M T tendency - gravity wave spectrum
# ###
# TTPXMLC
# K/S
# Top interf. temp. flux: molec. viscosity
# ###
# T_12_COS
# K
# Temperature 12hr. cos coeff.
# ###
# T_12_SIN
# K
# Temperature 12hr. sin coeff.
# ###
# T_24_COS
# K
# Temperature 24hr. cos coeff.
# ###
# T_24_SIN
# K
# Temperature 24hr. sin coeff.
# ###
# U
# m/s
# Zonal wind
# ###
# U10
# m/s
# 10m wind speed
# ###
# UE
# m/s
# Zonal ExB drift
# ###
# UIONTEND
# M/S2
# u-tendency due to ion drag
# ###
# UTEND1
# m/s2
# C&M U tendency   c < -40
# ###
# UTEND2
# m/s2
# C&M U tendency  -40 < c < -15
# ###
# UTEND3
# m/s2
# C&M U tendency  -15 < c <  15
# ###
# UTEND4
# m/s2
# C&M U tendency   15 < c <  40
# ###
# UTEND5
# m/s2
# C&M U tendency   40 < c
# ###
# UTGWORO
# m/s2
# U tendency - orographic gravity wave drag
# ###
# UTGWSPEC
# m/s2
# C&M U tendency - gravity wave spectrum
# ###
# UU
# m2/s2
# Zonal velocity squared
# ###
# UV3d
# M2/S2
# Meridional Flux of Zonal Momentum: 3D zon. mean
# ###
# UW3d
# M2/S2
# Vertical Flux of Zonal Momentum: 3D zon. mean
# ###
# U_12_COS
# m/s
# Zonal wind 12hr. cos coeff.
# ###
# U_12_SIN
# m/s
# Zonal wind 12hr. sin coeff.
# ###
# U_24_COS
# m/s
# Zonal wind 24hr. cos coeff.
# ###
# U_24_SIN
# m/s
# Zonal wind 24hr. sin coeff.
# ###
# V
# m/s
# Meridional wind
# ###
# VD01
# kg/kg/s
# Vertical diffusion of Q
# ###
# VE
# m/s
# Meridional ExB drift
# ###
# VERT
# kg/kg
# vertical tracer
# ###
# VERTSRC
# kg/kg/s
# VERT source/sink
# ###
# VIONTEND
# M/S2
# v-tendency due to ion drag
# ###
# VQ
# m/skg/kg
# Meridional water transport
# ###
# VT
# K m/s
# Meridional heat transport
# ###
# VTGWORO
# m/s2
# V tendency - orographic gravity wave drag
# ###
# VTGWSPEC
# m/s2
# C&M V tendency - gravity wave spectrum
# ###
# VTH3d
# MK/S
# Meridional Heat Flux: 3D zon. mean
# ###
# VU
# m2/s2
# Meridional flux of zonal momentum
# ###
# VV
# m2/s2
# Meridional velocity squared
# ###
# V_12_COS
# m/s
# Meridional wind 12hr. cos coeff.
# ###
# V_12_SIN
# m/s
# Meridional wind 12hr. sin coeff.
# ###
# V_24_COS
# m/s
# Meridional wind 24hr. cos coeff.
# ###
# V_24_SIN
# m/s
# Meridional wind 24hr. sin coeff.
# ###
# WE
# m/s
# Vertical ExB drift
# ###
# WTH3d
# MK/S
# Vertical Heat Flux: 3D zon. mean
# ###
# Z3
# m
# Geopotential Height (above sea level)
# ###
# e_SRF
# mol/mol
# electron concent in bottom layer
# ###
#
# Loading FSNS
# Saving FSNS
# /home/dmrivers/.cache/pypoetry/virtualenvs/co--V6REObM-py3.7/lib/python3.7/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# Done Saving FSNS
#
# Loading TS
# Saving TS
# Done Saving TS
#
# Loading PRECL
# Saving PRECL
# Done Saving PRECL
#
# Loading TSMN
# Saving TSMN
# Done Saving TSMN
#
# Loading Q
# Saving Q
# Done Saving Q

# %%
# Import some nuclear winter community land dataset variables
#
#   When imported, ImportClmData.py is run.
#
#   ImportClmData.py imports data from
#       Data/RawNuclearWinterData (if it exists, otherwise code will fail)
#
#   ImportClmData.py then saves it in geopandas format ([varname].pkl) to 
#       https://github.com/allfed/CropOpt/tree/master/Data/ImportedAsGeopandas
from src import import_clm_data
# Out:
# params to actually import:
# ['TG']
#
# All possible params:
# ###
# ZSOI
# m
# soil depth
# ###
# DZSOI
# m
# soil thickness
# ###
# WATSAT
# mm3/mm3
# saturated soil water content (porosity)
# ###
# SUCSAT
# mm
# saturated soil matric potential
# ###
# BSW
# unitless
# slope of soil water retention curve
# ###
# HKSAT
# unitless
# saturated hydraulic conductivity
# ###
# ACTUAL_IMMOB
# gN/m^2/s
# actual N immobilization
# ###
# AGNPP
# gC/m^2/s
# aboveground NPP
# ###
# ANN_FAREA_BURNED
# proportion
# annual total fractional area burned
# ###
# AR
# gC/m^2/s
# autotrophic respiration (MR + GR)
# ###
# BCDEP
# kg/m^2/s
# total BC deposition (dry+wet) from atmosphere
# ###
# BGNPP
# gC/m^2/s
# belowground NPP
# ###
# BTRAN
# unitless
# transpiration beta factor
# ###
# BUILDHEAT
# W/m^2
# heat flux from urban building interior to walls and roof
# ###
# COL_CTRUNC
# gC/m^2
# column-level sink for C truncation
# ###
# COL_FIRE_CLOSS
# gC/m^2/s
# total column-level fire C loss
# ###
# COL_FIRE_NLOSS
# gN/m^2/s
# total column-level fire N loss
# ###
# COL_NTRUNC
# gN/m^2
# column-level sink for N truncation
# ###
# CPOOL
# gC/m^2
# temporary photosynthate C pool
# ###
# CWDC
# gC/m^2
# coarse woody debris C
# ###
# CWDC_HR
# gC/m^2/s
# coarse woody debris C heterotrophic respiration
# ###
# CWDC_LOSS
# gC/m^2/s
# coarse woody debris C loss
# ###
# CWDN
# gN/m^2
# coarse woody debris N
# ###
# DEADCROOTC
# gC/m^2
# dead coarse root C
# ###
# DEADCROOTN
# gN/m^2
# dead coarse root N
# ###
# DEADSTEMC
# gC/m^2
# dead stem C
# ###
# DEADSTEMN
# gN/m^2
# dead stem N
# ###
# DENIT
# gN/m^2/s
# total rate of denitrification
# ###
# DISPVEGC
# gC/m^2
# displayed veg carbon, excluding storage and cpool
# ###
# DISPVEGN
# gN/m^2
# displayed vegetation nitrogen
# ###
# DSTDEP
# kg/m^2/s
# total dust deposition (dry+wet) from atmosphere
# ###
# DSTFLXT
# kg/m2/s
# total surface dust emission
# ###
# DWT_CLOSS
# gC/m^2/s
# total carbon loss from land cover conversion
# ###
# DWT_CONV_CFLUX
# gC/m^2/s
# conversion C flux (immediate loss to atm)
# ###
# DWT_CONV_NFLUX
# gN/m^2/s
# conversion N flux (immediate loss to atm)
# ###
# DWT_NLOSS
# gN/m^2/s
# total nitrogen loss from landcover conversion
# ###
# DWT_PROD100C_GAIN
# gC/m^2/s
# landcover change-driven addition to 100-yr wood product pool
# ###
# DWT_PROD100N_GAIN
# gN/m^2/s
# addition to 100-yr wood product pool
# ###
# DWT_PROD10C_GAIN
# gC/m^2/s
# landcover change-driven addition to 10-yr wood product pool
# ###
# DWT_PROD10N_GAIN
# gN/m^2/s
# addition to 10-yr wood product pool
# ###
# DWT_SEEDC_TO_DEADSTEM
# gC/m^2/s
# seed source to PFT-level deadstem
# ###
# DWT_SEEDC_TO_LEAF
# gC/m^2/s
# seed source to PFT-level leaf
# ###
# DWT_SEEDN_TO_DEADSTEM
# gN/m^2/s
# seed source to PFT-level deadstem
# ###
# DWT_SEEDN_TO_LEAF
# gN/m^2/s
# seed source to PFT-level leaf
# ###
# EFLX_DYNBAL
# W/m^2
# dynamic land cover change conversion energy flux
# ###
# EFLX_LH_TOT_R
# W/m^2
# Rural total evaporation
# ###
# EFLX_LH_TOT_U
# W/m^2
# Urban total evaporation
# ###
# ELAI
# m^2/m^2
# exposed one-sided leaf area index
# ###
# ER
# gC/m^2/s
# total ecosystem respiration, autotrophic + heterotrophic
# ###
# ERRH2O
# mm
# total water conservation error
# ###
# ERRH2OSNO
# mm
# imbalance in snow depth (liquid water)
# ###
# ERRSEB
# W/m^2
# surface energy conservation error
# ###
# ERRSOI
# W/m^2
# soil/lake energy conservation error
# ###
# ERRSOL
# W/m^2
# solar radiation conservation error
# ###
# ESAI
# m^2/m^2
# exposed one-sided stem area index
# ###
# FCEV
# W/m^2
# canopy evaporation
# ###
# FCOV
# unitless
# fractional impermeable area
# ###
# FCTR
# W/m^2
# canopy transpiration
# ###
# FGEV
# W/m^2
# ground evaporation
# ###
# FGR
# W/m^2
# heat flux into soil/snow including snow melt
# ###
# FGR12
# W/m^2
# heat flux between soil layers 1 and 2
# ###
# FGR_R
# W/m^2
# Rural heat flux into soil/snow including snow melt
# ###
# FGR_U
# W/m^2
# Urban heat flux into soil/snow including snow melt
# ###
# FIRA
# W/m^2
# net infrared (longwave) radiation
# ###
# FIRA_R
# W/m^2
# Rural net infrared (longwave) radiation
# ###
# FIRA_U
# W/m^2
# Urban net infrared (longwave) radiation
# ###
# FIRE
# W/m^2
# emitted infrared (longwave) radiation
# ###
# FIRESEASONL
# days
# annual fire season length
# ###
# FLDS
# W/m^2
# atmospheric longwave radiation
# ###
# FPG
# proportion
# fraction of potential gpp
# ###
# FPI
# proportion
# fraction of potential immobilization
# ###
# FPSN
# umol/m2s
# photosynthesis
# ###
# FROOTC
# gC/m^2
# fine root C
# ###
# FROOTC_ALLOC
# gC/m^2/s
# fine root C allocation
# ###
# FROOTC_LOSS
# gC/m^2/s
# fine root C loss
# ###
# FROOTN
# gN/m^2
# fine root N
# ###
# FSA
# W/m^2
# absorbed solar radiation
# ###
# FSAT
# unitless
# fractional area with water table at surface
# ###
# FSA_R
# W/m^2
# Rural absorbed solar radiation
# ###
# FSA_U
# W/m^2
# Urban absorbed solar radiation
# ###
# FSDS
# W/m^2
# atmospheric incident solar radiation
# ###
# FSDSND
# W/m^2
# direct nir incident solar radiation
# ###
# FSDSNDLN
# W/m^2
# direct nir incident solar radiation at local noon
# ###
# FSDSNI
# W/m^2
# diffuse nir incident solar radiation
# ###
# FSDSVD
# W/m^2
# direct vis incident solar radiation
# ###
# FSDSVDLN
# W/m^2
# direct vis incident solar radiation at local noon
# ###
# FSDSVI
# W/m^2
# diffuse vis incident solar radiation
# ###
# FSH
# W/m^2
# sensible heat
# ###
# FSH_G
# W/m^2
# sensible heat from ground
# ###
# FSH_NODYNLNDUSE
# W/m^2
# sensible heat not including correction for land use change
# ###
# FSH_R
# W/m^2
# Rural sensible heat
# ###
# FSH_U
# W/m^2
# Urban sensible heat
# ###
# FSH_V
# W/m^2
# sensible heat from veg
# ###
# FSM
# W/m^2
# snow melt heat flux
# ###
# FSM_R
# W/m^2
# Rural snow melt heat flux
# ###
# FSM_U
# W/m^2
# Urban snow melt heat flux
# ###
# FSNO
# unitless
# fraction of ground covered by snow
# ###
# FSR
# W/m^2
# reflected solar radiation
# ###
# FSRND
# W/m^2
# direct nir reflected solar radiation
# ###
# FSRNDLN
# W/m^2
# direct nir reflected solar radiation at local noon
# ###
# FSRNI
# W/m^2
# diffuse nir reflected solar radiation
# ###
# FSRVD
# W/m^2
# direct vis reflected solar radiation
# ###
# FSRVDLN
# W/m^2
# direct vis reflected solar radiation at local noon
# ###
# FSRVI
# W/m^2
# diffuse vis reflected solar radiation
# ###
# GC_HEAT1
# J/m^2
# initial gridcell total heat content
# ###
# GC_ICE1
# mm
# initial gridcell total ice content
# ###
# GC_LIQ1
# mm
# initial gridcell total liq content
# ###
# GPP
# gC/m^2/s
# gross primary production
# ###
# GR
# gC/m^2/s
# total growth respiration
# ###
# GROSS_NMIN
# gN/m^2/s
# gross rate of N mineralization
# ###
# H2OCAN
# mm
# intercepted water
# ###
# H2OSNO
# mm
# snow depth (liquid water)
# ###
# H2OSNO_TOP
# kg/m2
# mass of snow in top snow layer
# ###
# H2OSOI
# mm3/mm3
# volumetric soil water (vegetated landunits only)
# ###
# HC
# MJ/m2
# heat content of soil/snow/lake
# ###
# HCSOI
# MJ/m2
# soil heat content
# ###
# HEAT_FROM_AC
# W/m^2
# sensible heat flux put into canyon due to heat removed from air conditioning
# ###
# HR
# gC/m^2/s
# total heterotrophic respiration
# ###
# HTOP
# m
# canopy top
# ###
# LAISHA
# none
# shaded projected leaf area index
# ###
# LAISUN
# none
# sunlit projected leaf area index
# ###
# LAND_UPTAKE
# gC/m^2/s
# NEE minus LAND_USE_FLUX, negative for update
# ###
# LAND_USE_FLUX
# gC/m^2/s
# total C emitted from land cover conversion and wood product pools
# ###
# LEAFC
# gC/m^2
# leaf C
# ###
# LEAFC_ALLOC
# gC/m^2/s
# leaf C allocation
# ###
# LEAFC_LOSS
# gC/m^2/s
# leaf C loss
# ###
# LEAFN
# gN/m^2
# leaf N
# ###
# LITFALL
# gC/m^2/s
# litterfall (leaves and fine roots)
# ###
# LITHR
# gC/m^2/s
# litter heterotrophic respiration
# ###
# LITR1C
# gC/m^2
# litter labile C
# ###
# LITR1C_TO_SOIL1C
# gC/m^2/s
# decomp. of litter 1 C to SOM 1 C
# ###
# LITR1N
# gN/m^2
# litter labile N
# ###
# LITR2C
# gC/m^2
# litter cellulose C
# ###
# LITR2C_TO_SOIL2C
# gC/m^2/s
# decomp. of litter 2 C to SOM 2 C
# ###
# LITR2N
# gN/m^2
# litter cellulose N
# ###
# LITR3C
# gC/m^2
# litter lignin C
# ###
# LITR3C_TO_SOIL3C
# gC/m^2/s
# decomp. of litter 3 C to SOM 3 C
# ###
# LITR3N
# gN/m^2
# litter lignin N
# ###
# LITTERC
# gC/m^2
# litter C
# ###
# LITTERC_HR
# gC/m^2/s
# litter C heterotrophic respiration
# ###
# LITTERC_LOSS
# gC/m^2/s
# litter C loss
# ###
# LIVECROOTC
# gC/m^2
# live coarse root C
# ###
# LIVECROOTN
# gN/m^2
# live coarse root N
# ###
# LIVESTEMC
# gC/m^2
# live stem C
# ###
# LIVESTEMN
# gN/m^2
# live stem N
# ###
# MEAN_FIRE_PROB
# 0-1
# e-folding mean of daily fire probability
# ###
# MR
# gC/m^2/s
# maintenance respiration
# ###
# NBP
# gC/m^2/s
# net biome production, includes fire, landuse, and harvest flux, positive for sink
# ###
# NDEPLOY
# gN/m^2/s
# total N deployed in new growth
# ###
# NDEP_TO_SMINN
# gN/m^2/s
# atmospheric N deposition to soil mineral N
# ###
# NEE
# gC/m^2/s
# net ecosystem exchange of carbon, includes fire, landuse, harvest, and hrv_xsmrpool flux, positive for source
# ###
# NEP
# gC/m^2/s
# net ecosystem production, excludes fire, landuse, and harvest flux, positive for sink
# ###
# NET_NMIN
# gN/m^2/s
# net rate of N mineralization
# ###
# NFIX_TO_SMINN
# gN/m^2/s
# symbiotic/asymbiotic N fixation to soil mineral N
# ###
# NPP
# gC/m^2/s
# net primary production
# ###
# OCDEP
# kg/m^2/s
# total OC deposition (dry+wet) from atmosphere
# ###
# PBOT
# Pa
# atmospheric pressure
# ###
# PCO2
# Pa
# atmospheric partial pressure of CO2
# ###
# PFT_CTRUNC
# gC/m^2
# pft-level sink for C truncation
# ###
# PFT_FIRE_CLOSS
# gC/m^2/s
# total pft-level fire C loss
# ###
# PFT_FIRE_NLOSS
# gN/m^2/s
# total pft-level fire N loss
# ###
# PFT_NTRUNC
# gN/m^2
# pft-level sink for N truncation
# ###
# PLANT_NDEMAND
# gN/m^2/s
# N flux required to support initial GPP
# ###
# POTENTIAL_IMMOB
# gN/m^2/s
# potential N immobilization
# ###
# PROD100C
# gC/m^2
# 100-yr wood product C
# ###
# PROD100C_LOSS
# gC/m^2/s
# loss from 100-yr wood product pool
# ###
# PROD100N
# gN/m^2
# 100-yr wood product N
# ###
# PROD100N_LOSS
# gN/m^2/s
# loss from 100-yr wood product pool
# ###
# PROD10C
# gC/m^2
# 10-yr wood product C
# ###
# PROD10C_LOSS
# gC/m^2/s
# loss from 10-yr wood product pool
# ###
# PROD10N
# gN/m^2
# 10-yr wood product N
# ###
# PROD10N_LOSS
# gN/m^2/s
# loss from 10-yr wood product pool
# ###
# PRODUCT_CLOSS
# gC/m^2/s
# total carbon loss from wood product pools
# ###
# PRODUCT_NLOSS
# gN/m^2/s
# total N loss from wood product pools
# ###
# PSNSHA
# umolCO2/m^2/s
# shaded leaf photosynthesis
# ###
# PSNSHADE_TO_CPOOL
# gC/m^2/s
# C fixation from shaded canopy
# ###
# PSNSUN
# umolCO2/m^2/s
# sunlit leaf photosynthesis
# ###
# PSNSUN_TO_CPOOL
# gC/m^2/s
# C fixation from sunlit canopy
# ###
# Q2M
# kg/kg
# 2m specific humidity
# ###
# QBOT
# kg/kg
# atmospheric specific humidity
# ###
# QCHARGE
# mm/s
# aquifer recharge rate (vegetated landunits only)
# ###
# QDRAI
# mm/s
# sub-surface drainage
# ###
# QDRIP
# mm/s
# throughfall
# ###
# QFLX_ICE_DYNBAL
# mm/s
# ice dynamic land cover change conversion runoff flux
# ###
# QFLX_LIQ_DYNBAL
# mm/s
# liq dynamic land cover change conversion runoff flux
# ###
# QINFL
# mm/s
# infiltration
# ###
# QINTR
# mm/s
# interception
# ###
# QIRRIG
# mm/s
# water added through irrigation
# ###
# QOVER
# mm/s
# surface runoff
# ###
# QRGWL
# mm/s
# surface runoff at glaciers (liquid only), wetlands, lakes
# ###
# QRUNOFF
# mm/s
# total liquid runoff (does not include QSNWCPICE)
# ###
# QRUNOFF_NODYNLNDUSE
# mm/s
# total liquid runoff (does not include QSNWCPICE) not including correction for land use change
# ###
# QRUNOFF_R
# mm/s
# Rural total runoff
# ###
# QRUNOFF_U
# mm/s
# Urban total runoff
# ###
# QSNOMELT
# mm/s
# snow melt
# ###
# QSNWCPICE
# mm/s
# excess snowfall due to snow capping
# ###
# QSNWCPICE_NODYNLNDUSE
# mm H2O/s
# excess snowfall due to snow capping not including correction for land use change
# ###
# QSOIL
# mm/s
# Ground evaporation (soil/snow evaporation + soil/snow sublimation - dew)
# ###
# QVEGE
# mm/s
# canopy evaporation
# ###
# QVEGT
# mm/s
# canopy transpiration
# ###
# RAIN
# mm/s
# atmospheric rain
# ###
# RETRANSN
# gN/m^2
# plant pool of retranslocated N
# ###
# RETRANSN_TO_NPOOL
# gN/m^2/s
# deployment of retranslocated N
# ###
# RH2M
# %
# 2m relative humidity
# ###
# RH2M_R
# %
# Rural 2m specific humidity
# ###
# RH2M_U
# %
# Urban 2m relative humidity
# ###
# RR
# gC/m^2/s
# root respiration (fine root MR + total root GR)
# ###
# SABG
# W/m^2
# solar rad absorbed by ground
# ###
# SABV
# W/m^2
# solar rad absorbed by veg
# ###
# SEEDC
# gC/m^2
# pool for seeding new PFTs
# ###
# SEEDN
# gN/m^2
# pool for seeding new PFTs
# ###
# SMINN
# gN/m^2
# soil mineral N
# ###
# SMINN_LEACHED
# gN/m^2/s
# soil mineral N pool loss to leaching
# ###
# SMINN_TO_NPOOL
# gN/m^2/s
# deployment of soil mineral N uptake
# ###
# SMINN_TO_PLANT
# gN/m^2/s
# plant uptake of soil mineral N
# ###
# SNOBCMCL
# kg/m2
# mass of BC in snow column
# ###
# SNOBCMSL
# kg/m2
# mass of BC in top snow layer
# ###
# SNODSTMCL
# kg/m2
# mass of dust in snow column
# ###
# SNODSTMSL
# kg/m2
# mass of dust in top snow layer
# ###
# SNOOCMCL
# kg/m2
# mass of OC in snow column
# ###
# SNOOCMSL
# kg/m2
# mass of OC in top snow layer
# ###
# SNOW
# mm/s
# atmospheric snow
# ###
# SNOWDP
# m
# snow height
# ###
# SNOWICE
# kg/m2
# snow ice
# ###
# SNOWLIQ
# kg/m2
# snow liquid water
# ###
# SNOW_SINKS
# mm/s
# snow sinks (liquid water)
# ###
# SNOW_SOURCES
# mm/s
# snow sources (liquid water)
# ###
# SOIL1C
# gC/m^2
# soil organic matter C (fast pool)
# ###
# SOIL1N
# gN/m^2
# soil organic matter N (fast pool)
# ###
# SOIL2C
# gC/m^2
# soil organic matter C (medium pool)
# ###
# SOIL2N
# gN/m^2
# soil organic matter N (medium pool)
# ###
# SOIL3C
# gC/m^2
# soil organic matter C (slow pool)
# ###
# SOIL3N
# gN/m^2
# soil orgainc matter N (slow pool)
# ###
# SOIL4C
# gC/m^2
# soil organic matter C (slowest pool)
# ###
# SOIL4N
# gN/m^2
# soil orgainc matter N (slowest pool)
# ###
# SOILC
# gC/m^2
# soil C
# ###
# SOILC_HR
# gC/m^2/s
# soil C heterotrophic respiration
# ###
# SOILC_LOSS
# gC/m^2/s
# soil C loss
# ###
# SOILICE
# kg/m2
# soil ice (vegetated landunits only)
# ###
# SOILLIQ
# kg/m2
# soil liquid water (vegetated landunits only)
# ###
# SOILPSI
# MPa
# soil water potential in each soil layer
# ###
# SOILWATER_10CM
# kg/m2
# soil liquid water + ice in top 10cm of soil (veg landunits only)
# ###
# SOMHR
# gC/m^2/s
# soil organic matter heterotrophic respiration
# ###
# SR
# gC/m^2/s
# total soil respiration (HR + root resp)
# ###
# STORVEGC
# gC/m^2
# stored vegetation carbon, excluding cpool
# ###
# STORVEGN
# gN/m^2
# stored vegetation nitrogen
# ###
# SUPPLEMENT_TO_SMINN
# gN/m^2/s
# supplemental N supply
# ###
# SoilAlpha
# unitless
# factor limiting ground evap
# ###
# SoilAlpha_U
# unitless
# urban factor limiting ground evap
# ###
# TAUX
# kg/m/s^2
# zonal surface stress
# ###
# TAUY
# kg/m/s^2
# meridional surface stress
# ###
# TBOT
# K
# atmospheric air temperature
# ###
# TBUILD
# K
# internal urban building temperature
# ###
# TG
# K
# ground temperature
# ###
# TG_R
# K
# Rural ground temperature
# ###
# TG_U
# K
# Urban ground temperature
# ###
# THBOT
# K
# atmospheric air potential temperature
# ###
# TLAI
# none
# total projected leaf area index
# ###
# TLAKE
# K
# lake temperature
# ###
# TOTCOLC
# gC/m^2
# total column carbon, incl veg and cpool
# ###
# TOTCOLN
# gN/m^2
# total column-level N
# ###
# TOTECOSYSC
# gC/m^2
# total ecosystem carbon, incl veg but excl cpool
# ###
# TOTECOSYSN
# gN/m^2
# total ecosystem N
# ###
# TOTLITC
# gC/m^2
# total litter carbon
# ###
# TOTLITN
# gN/m^2
# total litter N
# ###
# TOTPFTC
# gC/m^2
# total pft-level carbon, including cpool
# ###
# TOTPFTN
# gN/m^2
# total PFT-level nitrogen
# ###
# TOTPRODC
# gC/m^2
# total wood product C
# ###
# TOTPRODN
# gN/m^2
# total wood product N
# ###
# TOTSOMC
# gC/m^2
# total soil organic matter carbon
# ###
# TOTSOMN
# gN/m^2
# total soil organic matter N
# ###
# TOTVEGC
# gC/m^2
# total vegetation carbon, excluding cpool
# ###
# TOTVEGN
# gN/m^2
# total vegetation nitrogen
# ###
# TREFMNAV
# K
# daily minimum of average 2-m temperature
# ###
# TREFMNAV_R
# K
# Rural daily minimum of average 2-m temperature
# ###
# TREFMNAV_U
# K
# Urban daily minimum of average 2-m temperature
# ###
# TREFMXAV
# K
# daily maximum of average 2-m temperature
# ###
# TREFMXAV_R
# K
# Rural daily maximum of average 2-m temperature
# ###
# TREFMXAV_U
# K
# Urban daily maximum of average 2-m temperature
# ###
# TSA
# K
# 2m air temperature
# ###
# TSAI
# none
# total projected stem area index
# ###
# TSA_R
# K
# Rural 2m air temperature
# ###
# TSA_U
# K
# Urban 2m air temperature
# ###
# TSOI
# K
# soil temperature (vegetated landunits only)
# ###
# TSOI_10CM
# K
# soil temperature in top 10cm of soil
# ###
# TSOI_ICE
# K
# soil temperature (ice landunits only)
# ###
# TV
# K
# vegetation temperature
# ###
# U10
# m/s
# 10-m wind
# ###
# URBAN_AC
# W/m^2
# urban air conditioning flux
# ###
# URBAN_HEAT
# W/m^2
# urban heating flux
# ###
# WA
# mm
# water in the unconfined aquifer (vegetated landunits only)
# ###
# WASTEHEAT
# W/m^2
# sensible heat flux from heating/cooling sources of urban waste heat
# ###
# WIND
# m/s
# atmospheric wind velocity magnitude
# ###
# WOODC
# gC/m^2
# wood C
# ###
# WOODC_ALLOC
# gC/m^2/s
# wood C allocation
# ###
# WOODC_LOSS
# gC/m^2/s
# wood C loss
# ###
# WOOD_HARVESTC
# gC/m^2/s
# wood harvest carbon (to product pools)
# ###
# WOOD_HARVESTN
# gN/m^2/s
# wood harvest N (to product pools)
# ###
# WT
# mm
# total water storage (unsaturated soil water + groundwater, veg landunits)
# ###
# XSMRPOOL
# gC/m^2
# temporary photosynthate C pool
# ###
# XSMRPOOL_RECOVER
# gC/m^2/s
# C flux assigned to recovery of negative xsmrpool
# ###
# ZBOT
# m
# atmospheric reference height
# ###
# ZWT
# m
# water table depth (vegetated landunits only)
# ###
#
# Loading TG
# Saving TG
# Done Saving TG
